# %% [markdown]
# <a href="https://colab.research.google.com/github/dnevo/myproj/blob/main/notebooks/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/dnevo/myproj.git

from myproj.tiny_train import run_demo
run_demo()
